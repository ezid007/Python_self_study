# %%
import requests


QUIZ_API = "http://opentdb.com/api.php?amount=1&type=boolean"
quiz_data = requests.get(QUIZ_API)

# %%
quiz_data.json()
# Out:
# {'response_code': 0,
#  'results': [{'type': 'boolean',
#    'difficulty': 'medium',
#    'category': 'History',
#    'question': 'The Fourth Crusade lasted from 1095-1099 AD.',
#    'correct_answer': 'False',
#    'incorrect_answers': ['True']}]}

# %%
quiz_data.json()["results"][0]['question']
# Out:
# 'The Fourth Crusade lasted from 1095-1099 AD.'
